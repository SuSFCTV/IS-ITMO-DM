# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
V = 42
E = 87
read_country = open("europe.txt")
read_edges = open("dist.txt")
country = []  
edges = [] 
G = nx.Graph() 
matrix = [[] for i in range(V)]
for i in range(V):
    pars_one = read_country.readline().split('.')
    num, name = pars_one[0], pars_one[1][:-1]
    country.append(name)

for i in range(E):
    pars_two = read_edges.readline().split()
    a, b = int(pars_two[0]), int(pars_two[1])
    matrix[a].append(b)
    matrix[b].append(a)
    edges.append([a, b])

for i in range(E):
    a, b = edges[i]
    G.add_edge(country[a], country[b])

# %%
colors_map = []
colors_dict = [1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.3, 0.2, 0]  
colors_friend = [[] for i in range(V)]  

for i in edges:
    x = i[0]
    y = i[1]
    z = 0
    for j in colors_dict:
        if not j in colors_friend[x] and not j in colors_friend[b]:
            c = j
            break

    colors_map.append(c)
    colors_friend[a].append(c)
    colors_friend[b].append(c)
edge_colors = []

print(colors_map)
# Out:
# [10, 9, 8, 7, 6, 5, 4, 10, 9, 10, 9, 10, 9, 8, 7, 6, 9, 10, 8, 7, 9, 10, 8, 7, 8, 10, 9, 7, 6, 5, 8, 7, 6, 5, 4, 2, 0, 6, 8, 10, 9, 8, 6, 10, 5, 10, 7, 10, 9, 10, 9, 9, 4, 5, 7, 4, 10, 4, 9, 8, 5, 8, 10, 10, 8, 7, 9, 7, 9, 8, 6, 4, 7, 6, 5, 10, 2, 10, 4, 9, 8, 7, 2, 8, 9, 2, 2]

# %%
# Посмотрим на полученный граф
plt.figure(figsize=(16, 12))
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), node_size=500)
nx.draw_networkx_labels(G, pos)
nx.draw_networkx_edges(G, pos, edge_color=colors_map)

plt.show()
